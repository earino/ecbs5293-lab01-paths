# %% [markdown]
# # Sales analysis — Lab 1
#
# Load the 2024 sales data and report revenue per region.
#
# Run cells in order. If a cell fails, **do not delete it** — read the error, then look at the filesystem.

# %%
import pandas as pd

# %%
df = pd.read_csv("raw/sales.csv")
df.head()

# %%
df["revenue"] = df["units"] * df["unit_price"]
df.groupby("region")["revenue"].sum().round(2)

# %% [markdown]
# ## Before you leave
#
# Fill in `DIAGNOSIS.md`. Part 3 wants the *raw output* of what you ran — `os.getcwd()`, `ls`, the traceback — not a description of it. Then explain it to your neighbour when the slide goes up, and submit the note to the Moodle checkpoint before you leave.
